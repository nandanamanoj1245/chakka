# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv(r'C:\Users\User\Downloads\heart_failure_clinical_records_dataset.csv')
data.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# ...

# %%
data.shape
# Out:
# (299, 13)

# %%
data.isna().sum()
# Out:
# age                         0
# anaemia                     0
# creatinine_phosphokinase    0
# diabetes                    0
# ejection_fraction           0
# high_blood_pressure         0
# platelets                   0
# serum_creatinine            0
# serum_sodium                0
# sex                         0
# smoking                     0
# time                        0
# DEATH_EVENT                 0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %%
data.describe()
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  299.000000  299.000000                299.000000  299.000000
# mean    60.833893    0.431438                581.839465    0.418060
# std     11.894809    0.496107                970.287881    0.494067
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     51.000000    0.000000                116.500000    0.000000
# 50%     60.000000    0.000000                250.000000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         299.000000           299.000000     299.000000
# mean           38.083612             0.351171  263358.029264
# std            11.834841             0.478136   97804.236869
# min            14.000000             0.000000   25100.000000
# ...

# %%
data.loc[data['diabetes']==0]
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 5    90.0        1                        47         0                 40
# ..    ...      ...                       ...       ...                ...
# 289  90.0        1                       337         0                 38
# 291  60.0        0                       320         0                 35
# 295  55.0        0                      1820         0                 38
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
data.isnull().sum()
# Out:
# age                         0
# anaemia                     0
# creatinine_phosphokinase    0
# diabetes                    0
# ejection_fraction           0
# high_blood_pressure         0
# platelets                   0
# serum_creatinine            0
# serum_sodium                0
# sex                         0
# smoking                     0
# time                        0
# DEATH_EVENT                 0
# dtype: int64

# %%
import matplotlib.pyplot as plt
from sklearn

# %%
x=data.drop("DEATH_EVENT",axis=1)
y=data["DEATH_EVENT"]
X_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=43)
x_train=x_train.astype(np.float3,2)
x_test=x_test.astype(np.float3,2)
y_train=y_train.astype(np.float3,2)
y_test=y_test.astype(np.float3,2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1232/2278020860.py in <module>
#       1 x=data.drop("DEATH_EVENT",axis=1)
#       2 y=data["DEATH_EVENT"]
# ----> 3 X_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=43)
#       4 x_train=x_train.astype(np.float3,2)
#       5 x_test=x_test.astype(np.float3,2)
#
# NameError: name 'train_test_split' is not defined

# %%
import stndardscaler
# Out:
#   File "C:\Users\User\AppData\Local\Temp/ipykernel_1232/1002309610.py", line 2
#     from sklearn.metrics
#                         ^
# SyntaxError: invalid syntax

# %%
scalar=standardscalar()
x_train=scaler.fit_transform(x_train)
x_test=scaler.transform(x_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1232/4078885870.py in <module>
# ----> 1 scalar=standardscalar()
#       2 x_train=scaler.fit_transform(x_train)
#       3 x_test=scaler.transform(x_test)
#
# NameError: name 'standardscalar' is not defined

# %%
import seborn as sns
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(),
annot=true,
camp="coolwarm")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1232/3586435182.py in <module>
# ----> 1 import seborn as sns
#       2 plt.figure(figsize=(10,8))
#       3 sns.heatmap(df.corr(),
#       4 annot=true,
#       5 camp="coolwarm")
#
# ModuleNotFoundError: No module named 'seborn'
